# %%
# %pwd
# Out:
# 'c:\\Users\\noham\\Desktop\\travail + cours\\scraping_books\\solutions'

# %%
import pandas as pd
df = pd.read_csv("outputs/categories/categorie_Mystery.csv")
df.head()
# Out:
#                                              Title    Price  \
# 0                                    Sharp Objects  Â£47.82
# 1                             In a Dark, Dark Wood  Â£19.63
# 2                              The Past Never Ends  Â£56.50
# 3                                 A Murder in Time  Â£16.64
# 4  The Murder of Roger Ackroyd (Hercule Poirot #4)  Â£44.10
#
#               Availability Rating               UPC Category  \
# 0  In stock (20 available)   Four  e00eb4fd7b871a48  Mystery
# 1  In stock (18 available)    One  19ed25f4641d5efd  Mystery
# 2  In stock (16 available)   Four  5ee94540d0749ea0  Mystery
# 3  In stock (16 available)    One  f733e8c19d40ec2e  Mystery
# 4  In stock (15 available)   Four  c7b5183f4d1d4efe  Mystery
#
#                                            Image URL  \
# 0  https://books.toscrape.com/media/cache/c0/59/c...
# 1  https://books.toscrape.com/media/cache/95/84/9...
# 2  https://books.toscrape.com/media/cache/9d/f2/9...
# ...
